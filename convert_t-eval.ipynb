# %%
import json
def write_json(Data, f_p):
    f = open(f_p, "w", encoding="utf-8")
    json.dump(Data, f, ensure_ascii=False, indent=2)
    f.close()

def read_json(f_p):
    f = open(f_p, "r", encoding="utf-8")
    Data = json.load(f)
    return Data

# %%
api_desp_path = "/Users/wqh/workspace/toolsbender/T-Eval/docs/api_descrip.json"
api_desps = read_json(api_desp_path)
print(len(api_desps))
# Out:
# 15

# %%
for api in api_desps:
    print("@"*30)
    print(api["tool_description"])
    print(len(api["api_list"]))
    for a in api["api_list"]:
        print("#"*20)
        print(a["name"])
        print(a["required_parameters"])
        print(a["return_data"])
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Search information from airbnb Short-term rental and housing informationoutside China
# 5
# ####################
# search_property_by_place
# [{'name': 'place', 'type': 'STRING', 'description': 'The name of the destination.'}]
# [{'name': 'property', 'description': 'a list of at most 3 properties, containing id, name, and address.'}]
# ####################
# get_property_details
# [{'name': 'propertyId', 'type': 'NUMBER', 'description': 'The ID of the property.'}]
# [{'name': 'title', 'description': 'The title of the property.'}, {'name': 'propertyType', 'description': 'The type of the property.'}, {'name': 'personCapacity', 'description': 'The capacity of the property.'}, {'name': 'rating', 'description': 'The rating of the property.'}, {'name': 'latitude', 'description': 'The latitude of the property.'}, {'name': 'longitude', 'description': 'The longitude of the property.'}]
# ####################
# check_availability
# ...
